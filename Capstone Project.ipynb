# %% [markdown]
# ### Import modules

# %%
import io
import pandas as pd
import numpy as np
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# ### Download wikipedia

# %%
wikipedia_page = 'https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'
file = requests.get(wikipedia_page).text

# %% [markdown]
# ### Parsing the data

# %%
soup = BeautifulSoup(file, 'html.parser')
table = soup.find_all('table', class_='sortable')
print ('Found {} table(s) in the extracted wiki-html.'.format( len (table ) ) )
# Out:
# Found 1 table(s) in the extracted wiki-html.

# %% [markdown]
# ### Changing to dataframe

# %%
table_headings = table[0].find_all('th') 
headings = [th.text.strip() for th in table_headings]
headings
# Out:
# ['Postcode', 'Borough', 'Neighbourhood']

# %%
headings[0] =  'Postalcode'

headings
# Out:
# ['Postalcode', 'Borough', 'Neighbourhood']

# %%
table_rows = []

for tr in table[0].find_all('tr'):
    rows = tr.find_all('td')
    if not rows: 
        continue
    row = [td.text.strip() for td in rows[:3]]
    table_rows.append(row)
table_rows
# Out:
# [['M1A', 'Not assigned', 'Not assigned'],
#  ['M2A', 'Not assigned', 'Not assigned'],
#  ['M3A', 'North York', 'Parkwoods'],
#  ['M4A', 'North York', 'Victoria Village'],
#  ['M5A', 'Downtown Toronto', 'Harbourfront'],
#  ['M5A', 'Downtown Toronto', 'Regent Park'],
#  ['M6A', 'North York', 'Lawrence Heights'],
#  ['M6A', 'North York', 'Lawrence Manor'],
#  ['M7A', "Queen's Park", 'Not assigned'],
#  ['M8A', 'Not assigned', 'Not assigned'],
#  ['M9A', 'Etobicoke', 'Islington Avenue'],
#  ['M1B', 'Scarborough', 'Rouge'],
#  ['M1B', 'Scarborough', 'Malvern'],
#  ['M2B', 'Not assigned', 'Not assigned'],
#  ['M3B', 'North York', 'Don Mills North'],
#  ['M4B', 'East York', 'Woodbine Gardens'],
#  ['M4B', 'East York', 'Parkview Hill'],
#  ['M5B', 'Downtown Toronto', 'Ryerson'],
#  ['M5B', 'Downtown Toronto', 'Garden District'],
#  ['M6B', 'North York', 'Glencairn'],
#  ['M7B', 'Not assigned', 'Not assigned'],
#  ['M8B', 'Not assigned', 'Not assigned'],
#  ['M9B', 'Etobicoke', 'Cloverdale'],
#  ['M9B', 'Etobicoke', 'Islington'],
#  ['M9B', 'Etobicoke', 'Martin Grove'],
#  ['M9B', 'Etobicoke', 'Princess Gardens'],
#  ['M9B', 'Etobicoke', 'West Deane Park'],
#  ['M1C', 'Scarborough', 'Highland Creek'],
#  ['M1C', 'Scarborough', 'Rouge Hill'],
#  ['M1C', 'Scarborough', 'Port Union'],
#  ['M2C', 'Not assigned', 'Not assigned'],
#  ['M3C', 'North York', 'Flemingdon Park'],
#  ['M3C', 'North York', 'Don Mills South'],
#  ['M4C', 'East York', 'Woodbine Heights'],
#  ['M5C', 'Downtown Toronto', 'St. James Town'],
#  ['M6C', 'York', 'Humewood-Cedarvale'],
#  ['M7C', 'Not assigned', 'Not assigned'],
#  ['M8C', 'Not assigned', 'Not assigned'],
#  ['M9C', 'Etobicoke', 'Bloordale Gardens'],
#  ['M9C', 'Etobicoke', 'Eringate'],
#  ['M9C', 'Etobicoke', 'Markland Wood'],
#  ['M9C', 'Etobicoke', 'Old Burnhamthorpe'],
#  ['M1E', 'Scarborough', 'Guildwood'],
#  ['M1E', 'Scarborough', 'Morningside'],
#  ['M1E', 'Scarborough', 'West Hill'],
#  ['M2E', 'Not assigned', 'Not assigned'],
#  ['M3E', 'Not assigned', 'Not assigned'],
#  ['M4E', 'East Toronto', 'The Beaches'],
#  ['M5E', 'Downtown Toronto', 'Berczy Park'],
#  ['M6E', 'York', 'Caledonia-Fairbanks'],
#  ['M7E', 'Not assigned', 'Not assigned'],
#  ['M8E', 'Not assigned', 'Not assigned'],
#  ['M9E', 'Not assigned', 'Not assigned'],
#  ['M1G', 'Scarborough', 'Woburn'],
#  ['M2G', 'Not assigned', 'Not assigned'],
#  ['M3G', 'Not assigned', 'Not assigned'],
#  ['M4G', 'East York', 'Leaside'],
#  ['M5G', 'Downtown Toronto', 'Central Bay Street'],
#  ['M6G', 'Downtown Toronto', 'Christie'],
#  ['M7G', 'Not assigned', 'Not assigned'],
#  ['M8G', 'Not assigned', 'Not assigned'],
#  ['M9G', 'Not assigned', 'Not assigned'],
#  ['M1H', 'Scarborough', 'Cedarbrae'],
#  ['M2H', 'North York', 'Hillcrest Village'],
#  ['M3H', 'North York', 'Bathurst Manor'],
#  ['M3H', 'North York', 'Downsview North'],
#  ['M3H', 'North York', 'Wilson Heights'],
#  ['M4H', 'East York', 'Thorncliffe Park'],
#  ['M5H', 'Downtown Toronto', 'Adelaide'],
#  ['M5H', 'Downtown Toronto', 'King'],
#  ['M5H', 'Downtown Toronto', 'Richmond'],
#  ['M6H', 'West Toronto', 'Dovercourt Village'],
#  ['M6H', 'West Toronto', 'Dufferin'],
#  ['M7H', 'Not assigned', 'Not assigned'],
#  ['M8H', 'Not assigned', 'Not assigned'],
#  ['M9H', 'Not assigned', 'Not assigned'],
#  ['M1J', 'Scarborough', 'Scarborough Village'],
#  ['M2J', 'North York', 'Fairview'],
#  ['M2J', 'North York', 'Henry Farm'],
#  ['M2J', 'North York', 'Oriole'],
#  ['M3J', 'North York', 'Northwood Park'],
#  ['M3J', 'North York', 'York University'],
#  ['M4J', 'East York', 'East Toronto'],
#  ['M5J', 'Downtown Toronto', 'Harbourfront East'],
#  ['M5J', 'Downtown Toronto', 'Toronto Islands'],
#  ['M5J', 'Downtown Toronto', 'Union Station'],
#  ['M6J', 'West Toronto', 'Little Portugal'],
#  ['M6J', 'West Toronto', 'Trinity'],
#  ['M7J', 'Not assigned', 'Not assigned'],
#  ['M8J', 'Not assigned', 'Not assigned'],
#  ['M9J', 'Not assigned', 'Not assigned'],
#  ['M1K', 'Scarborough', 'East Birchmount Park'],
#  ['M1K', 'Scarborough', 'Ionview'],
#  ['M1K', 'Scarborough', 'Kennedy Park'],
#  ['M2K', 'North York', 'Bayview Village'],
#  ['M3K', 'North York', 'CFB Toronto'],
#  ['M3K', 'North York', 'Downsview East'],
#  ['M4K', 'East Toronto', 'The Danforth West'],
#  ['M4K', 'East Toronto', 'Riverdale'],
#  ['M5K', 'Downtown Toronto', 'Design Exchange'],
#  ['M5K', 'Downtown Toronto', 'Toronto Dominion Centre'],
#  ['M6K', 'West Toronto', 'Brockton'],
#  ['M6K', 'West Toronto', 'Exhibition Place'],
#  ['M6K', 'West Toronto', 'Parkdale Village'],
#  ['M7K', 'Not assigned', 'Not assigned'],
#  ['M8K', 'Not assigned', 'Not assigned'],
#  ['M9K', 'Not assigned', 'Not assigned'],
#  ['M1L', 'Scarborough', 'Clairlea'],
#  ['M1L', 'Scarborough', 'Golden Mile'],
#  ['M1L', 'Scarborough', 'Oakridge'],
#  ['M2L', 'North York', 'Silver Hills'],
#  ['M2L', 'North York', 'York Mills'],
#  ['M3L', 'North York', 'Downsview West'],
#  ['M4L', 'East Toronto', 'The Beaches West'],
#  ['M4L', 'East Toronto', 'India Bazaar'],
#  ['M5L', 'Downtown Toronto', 'Commerce Court'],
#  ['M5L', 'Downtown Toronto', 'Victoria Hotel'],
#  ['M6L', 'North York', 'Maple Leaf Park'],
#  ['M6L', 'North York', 'North Park'],
#  ['M6L', 'North York', 'Upwood Park'],
#  ['M7L', 'Not assigned', 'Not assigned'],
#  ['M8L', 'Not assigned', 'Not assigned'],
#  ['M9L', 'North York', 'Humber Summit'],
#  ['M1M', 'Scarborough', 'Cliffcrest'],
#  ['M1M', 'Scarborough', 'Cliffside'],
#  ['M1M', 'Scarborough', 'Scarborough Village West'],
#  ['M2M', 'North York', 'Newtonbrook'],
#  ['M2M', 'North York', 'Willowdale'],
#  ['M3M', 'North York', 'Downsview Central'],
#  ['M4M', 'East Toronto', 'Studio District'],
#  ['M5M', 'North York', 'Bedford Park'],
#  ['M5M', 'North York', 'Lawrence Manor East'],
#  ['M6M', 'York', 'Del Ray'],
#  ['M6M', 'York', 'Keelsdale'],
#  ['M6M', 'York', 'Mount Dennis'],
#  ['M6M', 'York', 'Silverthorn'],
#  ['M7M', 'Not assigned', 'Not assigned'],
#  ['M8M', 'Not assigned', 'Not assigned'],
#  ['M9M', 'North York', 'Emery'],
#  ['M9M', 'North York', 'Humberlea'],
#  ['M1N', 'Scarborough', 'Birch Cliff'],
#  ['M1N', 'Scarborough', 'Cliffside West'],
#  ['M2N', 'North York', 'Willowdale South'],
#  ['M3N', 'North York', 'Downsview Northwest'],
#  ['M4N', 'Central Toronto', 'Lawrence Park'],
#  ['M5N', 'Central Toronto', 'Roselawn'],
#  ['M6N', 'York', 'The Junction North'],
#  ['M6N', 'York', 'Runnymede'],
#  ['M7N', 'Not assigned', 'Not assigned'],
#  ['M8N', 'Not assigned', 'Not assigned'],
#  ['M9N', 'York', 'Weston'],
#  ['M1P', 'Scarborough', 'Dorset Park'],
#  ['M1P', 'Scarborough', 'Scarborough Town Centre'],
#  ['M1P', 'Scarborough', 'Wexford Heights'],
#  ['M2P', 'North York', 'York Mills West'],
#  ['M3P', 'Not assigned', 'Not assigned'],
#  ['M4P', 'Central Toronto', 'Davisville North'],
#  ['M5P', 'Central Toronto', 'Forest Hill North'],
#  ['M5P', 'Central Toronto', 'Forest Hill West'],
#  ['M6P', 'West Toronto', 'High Park'],
#  ['M6P', 'West Toronto', 'The Junction South'],
#  ['M7P', 'Not assigned', 'Not assigned'],
#  ['M8P', 'Not assigned', 'Not assigned'],
#  ['M9P', 'Etobicoke', 'Westmount'],
#  ['M1R', 'Scarborough', 'Maryvale'],
#  ['M1R', 'Scarborough', 'Wexford'],
#  ['M2R', 'North York', 'Willowdale West'],
#  ['M3R', 'Not assigned', 'Not assigned'],
#  ['M4R', 'Central Toronto', 'North Toronto West'],
#  ['M5R', 'Central Toronto', 'The Annex'],
#  ['M5R', 'Central Toronto', 'North Midtown'],
#  ['M5R', 'Central Toronto', 'Yorkville'],
#  ['M6R', 'West Toronto', 'Parkdale'],
#  ['M6R', 'West Toronto', 'Roncesvalles'],
#  ['M7R', 'Mississauga', 'Canada Post Gateway Processing Centre'],
#  ['M8R', 'Not assigned', 'Not assigned'],
#  ['M9R', 'Etobicoke', 'Kingsview Village'],
#  ['M9R', 'Etobicoke', 'Martin Grove Gardens'],
#  ['M9R', 'Etobicoke', 'Richview Gardens'],
#  ['M9R', 'Etobicoke', 'St. Phillips'],
#  ['M1S', 'Scarborough', 'Agincourt'],
#  ['M2S', 'Not assigned', 'Not assigned'],
#  ['M3S', 'Not assigned', 'Not assigned'],
#  ['M4S', 'Central Toronto', 'Davisville'],
#  ['M5S', 'Downtown Toronto', 'Harbord'],
#  ['M5S', 'Downtown Toronto', 'University of Toronto'],
#  ['M6S', 'West Toronto', 'Runnymede'],
#  ['M6S', 'West Toronto', 'Swansea'],
#  ['M7S', 'Not assigned', 'Not assigned'],
#  ['M8S', 'Not assigned', 'Not assigned'],
#  ['M9S', 'Not assigned', 'Not assigned'],
#  ['M1T', 'Scarborough', 'Clarks Corners'],
#  ['M1T', 'Scarborough', 'Sullivan'],
#  ['M1T', 'Scarborough', "Tam O'Shanter"],
#  ['M2T', 'Not assigned', 'Not assigned'],
#  ['M3T', 'Not assigned', 'Not assigned'],
#  ['M4T', 'Central Toronto', 'Moore Park'],
#  ['M4T', 'Central Toronto', 'Summerhill East'],
#  ['M5T', 'Downtown Toronto', 'Chinatown'],
#  ['M5T', 'Downtown Toronto', 'Grange Park'],
#  ['M5T', 'Downtown Toronto', 'Kensington Market'],
#  ['M6T', 'Not assigned', 'Not assigned'],
#  ['M7T', 'Not assigned', 'Not assigned'],
#  ['M8T', 'Not assigned', 'Not assigned'],
#  ['M9T', 'Not assigned', 'Not assigned'],
#  ['M1V', 'Scarborough', 'Agincourt North'],
#  ['M1V', 'Scarborough', "L'Amoreaux East"],
#  ['M1V', 'Scarborough', 'Milliken'],
#  ['M1V', 'Scarborough', 'Steeles East'],
#  ['M2V', 'Not assigned', 'Not assigned'],
#  ['M3V', 'Not assigned', 'Not assigned'],
#  ['M4V', 'Central Toronto', 'Deer Park'],
#  ['M4V', 'Central Toronto', 'Forest Hill SE'],
#  ['M4V', 'Central Toronto', 'Rathnelly'],
#  ['M4V', 'Central Toronto', 'South Hill'],
#  ['M4V', 'Central Toronto', 'Summerhill West'],
#  ['M5V', 'Downtown Toronto', 'CN Tower'],
#  ['M5V', 'Downtown Toronto', 'Bathurst Quay'],
#  ['M5V', 'Downtown Toronto', 'Island airport'],
#  ['M5V', 'Downtown Toronto', 'Harbourfront West'],
#  ['M5V', 'Downtown Toronto', 'King and Spadina'],
#  ['M5V', 'Downtown Toronto', 'Railway Lands'],
#  ['M5V', 'Downtown Toronto', 'South Niagara'],
#  ['M6V', 'Not assigned', 'Not assigned'],
#  ['M7V', 'Not assigned', 'Not assigned'],
#  ['M8V', 'Etobicoke', 'Humber Bay Shores'],
#  ['M8V', 'Etobicoke', 'Mimico South'],
#  ['M8V', 'Etobicoke', 'New Toronto'],
#  ['M9V', 'Etobicoke', 'Albion Gardens'],
#  ['M9V', 'Etobicoke', 'Beaumond Heights'],
#  ['M9V', 'Etobicoke', 'Humbergate'],
#  ['M9V', 'Etobicoke', 'Jamestown'],
#  ['M9V', 'Etobicoke', 'Mount Olive'],
#  ['M9V', 'Etobicoke', 'Silverstone'],
#  ['M9V', 'Etobicoke', 'South Steeles'],
#  ['M9V', 'Etobicoke', 'Thistletown'],
#  ['M1W', 'Scarborough', "L'Amoreaux West"],
#  ['M1W', 'Scarborough', 'Steeles West'],
#  ['M2W', 'Not assigned', 'Not assigned'],
#  ['M3W', 'Not assigned', 'Not assigned'],
#  ['M4W', 'Downtown Toronto', 'Rosedale'],
#  ['M5W', 'Downtown Toronto', 'Stn A PO Boxes 25 The Esplanade'],
#  ['M6W', 'Not assigned', 'Not assigned'],
#  ['M7W', 'Not assigned', 'Not assigned'],
#  ['M8W', 'Etobicoke', 'Alderwood'],
#  ['M8W', 'Etobicoke', 'Long Branch'],
#  ['M9W', 'Etobicoke', 'Northwest'],
#  ['M1X', 'Scarborough', 'Upper Rouge'],
#  ['M2X', 'Not assigned', 'Not assigned'],
#  ['M3X', 'Not assigned', 'Not assigned'],
#  ['M4X', 'Downtown Toronto', 'Cabbagetown'],
#  ['M4X', 'Downtown Toronto', 'St. James Town'],
#  ['M5X', 'Downtown Toronto', 'First Canadian Place'],
#  ['M5X', 'Downtown Toronto', 'Underground city'],
#  ['M6X', 'Not assigned', 'Not assigned'],
#  ['M7X', 'Not assigned', 'Not assigned'],
#  ['M8X', 'Etobicoke', 'The Kingsway'],
#  ['M8X', 'Etobicoke', 'Montgomery Road'],
#  ['M8X', 'Etobicoke', 'Old Mill North'],
#  ['M9X', 'Not assigned', 'Not assigned'],
#  ['M1Y', 'Not assigned', 'Not assigned'],
#  ['M2Y', 'Not assigned', 'Not assigned'],
#  ['M3Y', 'Not assigned', 'Not assigned'],
#  ['M4Y', 'Downtown Toronto', 'Church and Wellesley'],
#  ['M5Y', 'Not assigned', 'Not assigned'],
#  ['M6Y', 'Not assigned', 'Not assigned'],
#  ['M7Y', 'East Toronto', 'Business reply mail Processing Centre969 Eastern'],
#  ['M8Y', 'Etobicoke', 'Humber Bay'],
#  ['M8Y', 'Etobicoke', "King's Mill Park"],
#  ['M8Y', 'Etobicoke', 'Kingsway Park South East'],
#  ['M8Y', 'Etobicoke', 'Mimico NE'],
#  ['M8Y', 'Etobicoke', 'Old Mill South'],
#  ['M8Y', 'Etobicoke', 'The Queensway East'],
#  ['M8Y', 'Etobicoke', 'Royal York South East'],
#  ['M8Y', 'Etobicoke', 'Sunnylea'],
#  ['M9Y', 'Not assigned', 'Not assigned'],
#  ['M1Z', 'Not assigned', 'Not assigned'],
#  ['M2Z', 'Not assigned', 'Not assigned'],
#  ['M3Z', 'Not assigned', 'Not assigned'],
#  ['M4Z', 'Not assigned', 'Not assigned'],
#  ['M5Z', 'Not assigned', 'Not assigned'],
#  ['M6Z', 'Not assigned', 'Not assigned'],
#  ['M7Z', 'Not assigned', 'Not assigned'],
#  ['M8Z', 'Etobicoke', 'Kingsway Park South West'],
#  ['M8Z', 'Etobicoke', 'Mimico NW'],
#  ['M8Z', 'Etobicoke', 'The Queensway West'],
#  ['M8Z', 'Etobicoke', 'Royal York South West'],
#  ['M8Z', 'Etobicoke', 'South of Bloor'],
#  ['M9Z', 'Not assigned', 'Not assigned']]

# %%
Postal_Codes_Canada = pd.DataFrame(table_rows, columns=headings)
Postal_Codes_Canada.head()
# Out:
#   Postalcode           Borough     Neighbourhood
# 0        M1A      Not assigned      Not assigned
# 1        M2A      Not assigned      Not assigned
# 2        M3A        North York         Parkwoods
# 3        M4A        North York  Victoria Village
# 4        M5A  Downtown Toronto      Harbourfront

# %% [markdown]
# ### Getting rid of "Not assigned" values

# %%
Postal_Codes_Canada.replace(to_replace='Not assigned', value=np.NaN, inplace=True)
Postal_Codes_Canada.dropna(axis=0, subset=['Borough'], inplace=True)
Postal_Codes_Canada.reset_index(drop = True, inplace = True)

# %%
Postal_Codes_Canada.head()
# Out:
#   Postalcode           Borough     Neighbourhood
# 0        M3A        North York         Parkwoods
# 1        M4A        North York  Victoria Village
# 2        M5A  Downtown Toronto      Harbourfront
# 3        M5A  Downtown Toronto       Regent Park
# 4        M6A        North York  Lawrence Heights

# %%
s = Postal_Codes_Canada['Neighbourhood'].isna()
print (Postal_Codes_Canada['Borough'].loc[s])
Postal_Codes_Canada['Neighbourhood'].loc[s] = Postal_Codes_Canada['Borough'].loc[s]
# Out:
# 6    Queen's Park
# Name: Borough, dtype: object

# %%
groupby = Postal_Codes_Canada.groupby(['Postalcode','Borough'])

rows = []

for n,g in groupby:
    r = [ n[0], n[1], (', '.join(g['Neighbourhood']) )]
    rows.append(r)

Postal_Codes_Canada = pd.DataFrame(rows, columns=headings)
Postal_Codes_Canada.shape
# Out:
# (103, 3)

# %% [markdown]
# ### geographical coordinates of the neighborhoods

# %%
f =requests.get("https://cocl.us/Geospatial_data/Geospatial_Coordinates.csv").content
df=pd.read_csv(io.StringIO(f.decode('utf-8')))

# %%
df.head()
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476

# %%
df.columns = ['Postalcode','Latitude','Longitude']

# %%
geo_toronto = pd.merge(Postal_Codes_Canada, df, on='Postalcode')

# %%
geo_toronto.head()
# Out:
#   Postalcode      Borough                           Neighbourhood   Latitude  \
# 0        M1B  Scarborough                          Rouge, Malvern  43.806686
# 1        M1C  Scarborough  Highland Creek, Rouge Hill, Port Union  43.784535
# 2        M1E  Scarborough       Guildwood, Morningside, West Hill  43.763573
# 3        M1G  Scarborough                                  Woburn  43.770992
# 4        M1H  Scarborough                               Cedarbrae  43.773136
#
#    Longitude
# 0 -79.194353
# 1 -79.160497
# 2 -79.188711
# 3 -79.216917
# 4 -79.239476

# %% [markdown]
# ### Creating Map

# %%
import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files

# !conda install -c conda-forge geopy --yes # uncomment this line if you haven't completed the Foursquare API lab
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

# !conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library

print('Libraries imported.')
# Out:
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /anaconda3
#
#   added / updated specs:
#     - geopy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     r-plyr-1.8.4               |   r351h9d2a408_2         836 KB  conda-forge
#     freetype-2.8.1             |       hfa320df_1         830 KB  conda-forge
#     pango-1.40.14              |                0         520 KB  conda-forge
#     r-cvst-0.2_2               |   r351h6115d3f_0         100 KB  conda-forge
#     r-munsell-0.5.0            |   r351h6115d3f_1         243 KB  conda-forge
#     r-repr-0.15.0              |   r351hf348343_0         105 KB
#     r-dimred-0.1.0             |   r351h6115d3f_2         620 KB  conda-forge
#     xorg-libxrender-0.9.10     |       h470a237_2          24 KB  conda-forge
#     r-modelr-0.1.2             |   r351h6115d3f_1         211 KB  conda-forge
#     xorg-libx11-1.6.6          |       h470a237_0         841 KB  conda-forge
#     r-rcurl-1.95_4.11          |   r351h86b9717_2         861 KB  conda-forge
#     r-tibble-1.4.2             |   r351hc070d10_2         227 KB  conda-forge
#     r-caret-6.0_80             |   r351hc070d10_1         5.9 MB  conda-forge
#     r-quantmod-0.4_13          |   r351hf348343_0         952 KB
#     r-rpart-4.1_13             |   r351hc070d10_2         912 KB  conda-forge
#     r-lazyeval-0.2.1           |   r351hc070d10_2         158 KB  conda-forge
#     r-xtable-1.8_3             |           r351_0         738 KB  conda-forge
#     r-rjava-0.9_10             |   r351h6402f54_0         672 KB
#     jpeg-9c                    |       h470a237_1         245 KB  conda-forge
#     r-yaml-2.2.0               |   r351hc070d10_1         111 KB  conda-forge
#     r-digest-0.6.18            |   r351hc070d10_0         154 KB  conda-forge
#     r-data.table-1.11.4        |   r351hc070d10_2         1.4 MB  conda-forge
#     r-recommended-3.5.1        |           r351_1           3 KB  conda-forge
#     r-sourcetools-0.1.7        |   r351hfc679d8_0          57 KB  conda-forge
#     r-recipes-0.1.3            |   r351h6115d3f_1         1.2 MB  conda-forge
#     r-irkernel-0.8.12          |           r351_0         199 KB
#     r-irdisplay-0.5.0          |   r351hf348343_0          34 KB
#     r-rlang-0.2.2              |   r351h470a237_0         785 KB  conda-forge
#     r-base-3.5.1               |       h4fe35fd_1        22.8 MB  conda-forge
#     r-rappdirs-0.3.1           |   r351hc070d10_2          96 KB  conda-forge
#     r-utf8-1.1.4               |   r351hc070d10_0         157 KB  conda-forge
#     r-rvest-0.3.2              |   r351h6115d3f_1         888 KB  conda-forge
#     r-sparklyr-0.8.4           |   r351h6115d3f_1         2.7 MB  conda-forge
#     r-lubridate-1.7.4          |   r351h9d2a408_1         1.1 MB  conda-forge
#     r-backports-1.1.2          |   r351hc070d10_1          52 KB  conda-forge
#     r-zoo-1.8_3                |   r351hc070d10_0         1.1 MB  conda-forge
#     r-xfun-0.3                 |   r351h6115d3f_1         151 KB  conda-forge
#     r-rematch-1.0.1            |   r351h6115d3f_1          17 KB  conda-forge
#     r-tinytex-0.8              |   r351h6115d3f_0          90 KB  conda-forge
#     r-drr-0.0.3                |   r351h6115d3f_1         172 KB  conda-forge
#     r-ps-1.1.0                 |   r351hc070d10_1         188 KB  conda-forge
#     r-fansi-0.3.0              |   r351hc070d10_0         165 KB  conda-forge
#     r-pkgconfig-2.0.2          |   r351h6115d3f_1          23 KB  conda-forge
#     r-randomforest-4.6_14      |   r351h364d78e_0         227 KB  conda-forge
#     r-knitr-1.20               |   r351h6115d3f_1         1.0 MB  conda-forge
#     xorg-xextproto-7.3.0       |       h470a237_2          27 KB  conda-forge
#     r-kernlab-0.9_27           |   r351h9d2a408_0         2.1 MB  conda-forge
#     r-callr-3.0.0              |   r351h6115d3f_0         189 KB  conda-forge
#     r-ipred-0.9_7              |   r351hc070d10_1         395 KB  conda-forge
#     r-mgcv-1.8_24              |   r351hc070d10_2         2.4 MB  conda-forge
#     geopy-1.17.0               |             py_0          49 KB  conda-forge
#     r-uuid-0.1_2               |   r351hc070d10_1          20 KB  conda-forge
#     r-highr-0.7                |   r351h6115d3f_1          46 KB  conda-forge
#     r-robustbase-0.93_2        |   r351h364d78e_0         3.0 MB  conda-forge
#     r-rcpproll-0.3.0           |   r351h9d2a408_0         130 KB  conda-forge
#     r-iterators-1.0.10         |   r351h6115d3f_1         333 KB  conda-forge
#     pthread-stubs-0.4          |       h470a237_1           5 KB  conda-forge
#     prometheus_client-0.4.1    |             py_0          32 KB  conda-forge
#     r-glue-1.3.0               |   r351h470a237_2          93 KB  conda-forge
#     gsl-2.2.1                  |       h002c638_3         2.7 MB
#     geographiclib-1.49         |             py_0          32 KB  conda-forge
#     conda-4.5.11               |        py36_1000         651 KB  conda-forge
#     r-readxl-1.1.0             |   r351h9d2a408_2         873 KB  conda-forge
#     r-tidyr-0.8.1              |   r351h9d2a408_2         443 KB  conda-forge
#     xorg-libsm-1.2.3           |       h470a237_0          24 KB  conda-forge
#     r-promises-1.0.1           |   r351h9d2a408_0         181 KB  conda-forge
#     libedit-3.1.20170329       |       haf1bffa_1         155 KB  conda-forge
#     ncurses-6.1                |       hfc679d8_1         1.2 MB  conda-forge
#     r-base64enc-0.1_3          |   r351hc070d10_2          42 KB  conda-forge
#     r-xml2-1.2.0               |   r351h9d2a408_2         367 KB  conda-forge
#     r-formatr-1.5              |   r351h6115d3f_1         157 KB  conda-forge
#     xorg-renderproto-0.11.1    |       h470a237_2           8 KB  conda-forge
#     r-bitops-1.0_6             |   r351hc070d10_2          37 KB  conda-forge
#     r-class-7.3_14             |   r351hc070d10_2         102 KB  conda-forge
#     r-lattice-0.20_35          |   r351hc070d10_0         1.1 MB  conda-forge
#     r-maps-3.3.0               |   r351hc070d10_2         3.4 MB  conda-forge
#     r-broom-0.5.0              |   r351h6115d3f_2         1.9 MB  conda-forge
#     r-pillar-1.3.0             |   r351h6115d3f_0         168 KB  conda-forge
#     r-psych-1.8.4              |   r351h6115d3f_1         5.5 MB  conda-forge
#     r-survival-2.42_6          |   r351hc070d10_1         4.3 MB  conda-forge
#     r-foreign-0.8_71           |   r351hc070d10_2         273 KB  conda-forge
#     r-kernsmooth-2.23_15       |   r351h364d78e_2          94 KB  conda-forge
#     r-spatial-7.3_11           |   r351hc070d10_2         147 KB  conda-forge
#     r-bindr-0.1.1              |   r351h6115d3f_1          20 KB  conda-forge
#     r-sfsmisc-1.1_2            |   r351h6115d3f_0         617 KB  conda-forge
#     r-catools-1.17.1.1         |   r351h9d2a408_2         217 KB  conda-forge
#     r-dbi-1.0.0                |   r351h6115d3f_1         880 KB  conda-forge
#     r-hms-0.4.2                |   r351h6115d3f_0          71 KB  conda-forge
#     r-labeling-0.3             |   r351h6115d3f_1          64 KB  conda-forge
#     r-markdown-0.8             |   r351hc070d10_3         133 KB  conda-forge
#     krb5-1.14.6                |                0         1.2 MB  conda-forge
#     r-magic-1.5_8              |   r351h6115d3f_0         587 KB  conda-forge
#     r-rjdbc-0.2_7.1            |   r351hf348343_0         101 KB
#     r-ddalpha-1.3.4            |   r351he0ffe0d_1         1.2 MB  conda-forge
#     r-tidyverse-1.2.1          |   r351h6115d3f_1          97 KB  conda-forge
#     r-rprojroot-1.3_2          |   r351h6115d3f_1          92 KB  conda-forge
#     r-geometry-0.3_6           |   r351hc070d10_2         409 KB  conda-forge
#     r-timedate-3043.102        |   r351h6115d3f_0         1.5 MB  conda-forge
#     r-glmnet-2.0_16            |   r351h0b560c1_0         1.4 MB
#     r-whisker-0.3_2            |   r351h6115d3f_1          77 KB  conda-forge
#     r-jsonlite-1.5             |   r351hc070d10_2         1.1 MB  conda-forge
#     r-forcats-0.3.0            |   r351h6115d3f_1         222 KB  conda-forge
#     r-scales-1.0.0             |   r351h9d2a408_1         571 KB  conda-forge
#     r-httpuv-1.4.5             |   r351hfc679d8_1         491 KB  conda-forge
#     r-boot-1.3_20              |           r351_0         624 KB  conda-forge
#     r-profvis-0.3.5            |   r351h6402f54_0         164 KB
#     r-bit64-0.9_7              |   r351hc070d10_0         453 KB  conda-forge
#     r-modelmetrics-1.1.0       |   r351h9d2a408_2         127 KB  conda-forge
#     r-odbc-1.1.5               |   r351h0a44026_0         431 KB
#     r-numderiv-2016.8_1        |   r351h6115d3f_1         123 KB  conda-forge
#     r-ttr-0.23_3               |   r351h0b560c1_0         505 KB
#     r-miniui-0.1.1.1           |   r351h6115d3f_0          50 KB  conda-forge
#     r-blob-1.1.1               |           r351_1          27 KB  conda-forge
#     xorg-libxext-1.3.3         |       h470a237_4          42 KB  conda-forge
#     r-reshape2-1.4.3           |   r351h9d2a408_2         139 KB  conda-forge
#     r-colorspace-1.3_2         |   r351hc070d10_2         507 KB  conda-forge
#     r-evaluate-0.11            |   r351h6115d3f_0          75 KB  conda-forge
#     xorg-kbproto-1.0.7         |       h470a237_2          26 KB  conda-forge
#     libxcb-1.13                |       h470a237_2         344 KB  conda-forge
#     r-bindrcpp-0.2.2           |   r351h9d2a408_1         106 KB  conda-forge
#     r-config-0.3               |   r351h6115d3f_1          38 KB  conda-forge
#     r-rbokeh-0.6.3             |           r351_0         4.1 MB
#     r-pbdzmq-0.3_3             |   r351h32998d9_0         387 KB
#     r-essentials-3.5.1         |           r351_0           5 KB
#     r-mongolite-1.6            |   r351h6402f54_0         331 KB
#     r-prettyunits-1.0.2        |   r351h6115d3f_1          34 KB  conda-forge
#     r-pls-2.7_0                |   r351h6115d3f_0         1.2 MB  conda-forge
#     r-deoptimr-1.0_8           |   r351h6115d3f_1          55 KB  conda-forge
#     r-viridislite-0.3.0        |   r351h6115d3f_1          63 KB  conda-forge
#     notebook-5.7.0             |        py36_1000         7.3 MB  conda-forge
#     r-httr-1.3.1               |   r351h6115d3f_1         439 KB  conda-forge
#     r-haven-1.1.2              |   r351h9d2a408_2         354 KB  conda-forge
#     r-later-0.7.3              |   r351h9d2a408_0         117 KB  conda-forge
#     r-pki-0.1_5.1              |   r351hc070d10_0         104 KB  conda-forge
#     r-selectr-0.4_1            |   r351h6115d3f_0         368 KB  conda-forge
#     r-prodlim-2018.04.18       |   r351h9d2a408_2         407 KB  conda-forge
#     r-packrat-0.4.9_3          |   r351h6115d3f_1         460 KB  conda-forge
#     r-nlme-3.1_137             |   r351h364d78e_0         2.2 MB  conda-forge
#     r-bh-1.66.0_1              |           r351_1        10.0 MB  conda-forge
#     r-mass-7.3_50              |   r351hc070d10_2         1.1 MB  conda-forge
#     ca-certificates-2018.8.24  |       ha4d7672_0         136 KB  conda-forge
#     r-assertthat-0.2.0         |   r351h6115d3f_1          68 KB  conda-forge
#     r-openssl-1.0.2            |   r351h9f97512_0         1.1 MB  conda-forge
#     r-tidyselect-0.2.4         |   r351h9d2a408_2         152 KB  conda-forge
#     r-rjsonio-1.3_0            |   r351h9d2a408_2        1020 KB  conda-forge
#     xorg-libice-1.0.9          |       h470a237_4          57 KB  conda-forge
#     r-squarem-2017.10_1        |   r351h6115d3f_1         300 KB  conda-forge
#     r-rmarkdown-1.10           |   r351h6115d3f_1         2.4 MB  conda-forge
#     r-gtable-0.2.0             |   r351h6115d3f_1          95 KB  conda-forge
#     _r-mutex-1.0.0             |            mro_2           2 KB
#     r-cellranger-1.1.0         |   r351h6115d3f_1         105 KB  conda-forge
#     r-magrittr-1.5             |   r351h6115d3f_1         164 KB  conda-forge
#     r-r6-2.2.2                 |   r351h6115d3f_1         275 KB  conda-forge
#     r-readr-1.1.1              |   r351h9d2a408_2         700 KB  conda-forge
#     r-plogr-0.2.0              |   r351h6115d3f_1          18 KB  conda-forge
#     r-purrr-0.2.5              |   r351hc070d10_1         282 KB  conda-forge
#     r-rcolorbrewer-1.1_2       |   r351h6115d3f_1          58 KB  conda-forge
#     r-shiny-1.1.0              |           r351_0         3.2 MB  conda-forge
#     r-curl-3.2                 |   r351hc070d10_2         406 KB  conda-forge
#     openssl-1.0.2p             |       h470a237_1         2.9 MB  conda-forge
#     r-rsconnect-0.8.8          |   r351h6115d3f_0         504 KB  conda-forge
#     xorg-libxdmcp-1.1.2        |       h470a237_7          15 KB  conda-forge
#     r-hexbin-1.27.2            |   r351h364d78e_2         865 KB  conda-forge
#     r-dplyr-0.7.6              |   r351h9d2a408_1         1.8 MB  conda-forge
#     r-mnormt-1.5_5             |   r351h364d78e_1          91 KB  conda-forge
#     unixodbc-2.3.7             |       h09ba92c_0         271 KB  conda-forge
#     r-htmltools-0.3.6          |   r351hfc679d8_2         192 KB  conda-forge
#     r-htmlwidgets-1.2          |   r351h6115d3f_0         691 KB  conda-forge
#     r-bit-1.1_12               |   r351h470a237_2         224 KB  conda-forge
#     r-reprex-0.2.0             |   r351h6115d3f_1         397 KB  conda-forge
#     r-gower-0.1.2              |   r351hc070d10_2          48 KB  conda-forge
#     r-processx-3.2.0           |   r351hc070d10_1         167 KB  conda-forge
#     r-mime-0.5                 |   r351hc070d10_2          48 KB  conda-forge
#     r-dichromat-2.0_0          |   r351hf348343_4         151 KB
#     r-nnet-7.3_12              |   r351hc070d10_2         126 KB  conda-forge
#     r-ggplot2-3.0.0            |   r351h6115d3f_1         3.5 MB  conda-forge
#     r-foreach-1.4.4            |   r351h6115d3f_1         403 KB  conda-forge
#     r-abind-1.4_5              |   r351h6115d3f_0          66 KB  conda-forge
#     xorg-libxau-1.0.8          |       h470a237_6          11 KB  conda-forge
#     xorg-xproto-7.0.31         |       h470a237_7          72 KB  conda-forge
#     r-rstudioapi-0.7           |   r351h6115d3f_1         134 KB  conda-forge
#     r-clipr-0.4.1              |   r351h6115d3f_1          50 KB  conda-forge
#     r-matrix-1.2_14            |   r351hc070d10_2         3.6 MB  conda-forge
#     r-rcpp-0.12.17             |   r351h9d2a408_2         3.5 MB  conda-forge
#     r-lava-1.6.3               |   r351h6115d3f_1         2.2 MB  conda-forge
#     r-stringr-1.3.1            |   r351h6115d3f_1         186 KB  conda-forge
#     r-stringi-1.2.4            |   r351h9d2a408_1        11.7 MB  conda-forge
#     r-codetools-0.2_15         |   r351h6115d3f_1          91 KB  conda-forge
#     r-withr-2.1.2              |   r351h6115d3f_0         172 KB  conda-forge
#     tk-8.6.8                   |       ha92aebf_0         3.0 MB  conda-forge
#     r-dbplyr-1.2.2             |   r351h6115d3f_1         534 KB  conda-forge
#     certifi-2018.8.24          |        py36_1001         139 KB  conda-forge
#     r-cli-1.0.0                |   r351h6115d3f_1         323 KB  conda-forge
#     r-cluster-2.0.7_1          |   r351h364d78e_0         537 KB  conda-forge
#     r-xts-0.11_1               |   r351hc070d10_0         904 KB  conda-forge
#     r-crayon-1.3.4             |   r351h6115d3f_1         745 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:       176.5 MB
# The following NEW packages will be INSTALLED:
#
#     geographiclib:     1.49-py_0                conda-forge
#     geopy:             1.17.0-py_0              conda-forge
#     libxcb:            1.13-h470a237_2          conda-forge
#     prometheus_client: 0.4.1-py_0               conda-forge
#     pthread-stubs:     0.4-h470a237_1           conda-forge
#     r-abind:           1.4_5-r351h6115d3f_0     conda-forge
#     r-fansi:           0.3.0-r351hc070d10_0     conda-forge
#     r-geometry:        0.3_6-r351hc070d10_2     conda-forge
#     r-later:           0.7.3-r351h9d2a408_0     conda-forge
#     r-magic:           1.5_8-r351h6115d3f_0     conda-forge
#     r-pls:             2.7_0-r351h6115d3f_0     conda-forge
#     r-prettyunits:     1.0.2-r351h6115d3f_1     conda-forge
#     r-processx:        3.2.0-r351hc070d10_1     conda-forge
#     r-promises:        1.0.1-r351h9d2a408_0     conda-forge
#     r-ps:              1.1.0-r351hc070d10_1     conda-forge
#     r-squarem:         2017.10_1-r351h6115d3f_1 conda-forge
#     r-tinytex:         0.8-r351h6115d3f_0       conda-forge
#     r-xfun:            0.3-r351h6115d3f_1       conda-forge
#     xorg-kbproto:      1.0.7-h470a237_2         conda-forge
#     xorg-libice:       1.0.9-h470a237_4         conda-forge
#     xorg-libsm:        1.2.3-h470a237_0         conda-forge
#     xorg-libx11:       1.6.6-h470a237_0         conda-forge
#     xorg-libxau:       1.0.8-h470a237_6         conda-forge
#     xorg-libxdmcp:     1.1.2-h470a237_7         conda-forge
#     xorg-libxext:      1.3.3-h470a237_4         conda-forge
#     xorg-libxrender:   0.9.10-h470a237_2        conda-forge
#     xorg-renderproto:  0.11.1-h470a237_2        conda-forge
#     xorg-xextproto:    7.3.0-h470a237_2         conda-forge
#     xorg-xproto:       7.0.31-h470a237_7        conda-forge
#
# The following packages will be UPDATED:
#
#     _r-mutex:          1.0.0-anacondar_1                    --> 1.0.0-mro_2
#     ca-certificates:   2018.03.07-0                         --> 2018.8.24-ha4d7672_0      conda-forge
#     certifi:           2018.8.24-py36_1                     --> 2018.8.24-py36_1001       conda-forge
#     conda:             4.5.11-py36_0                        --> 4.5.11-py36_1000          conda-forge
#     freetype:          2.8-h12048fb_1                       --> 2.8.1-hfa320df_1          conda-forge
#     jpeg:              9b-he5867d9_2                        --> 9c-h470a237_1             conda-forge
#     krb5:              1.14.2-h9a779f2_6                    --> 1.14.6-0                  conda-forge
#     libedit:           3.1-hb4e282d_0                       --> 3.1.20170329-haf1bffa_1   conda-forge
#     ncurses:           6.0-hd04f020_2                       --> 6.1-hfc679d8_1            conda-forge
#     notebook:          5.5.0-py36_0                         --> 5.7.0-py36_1000           conda-forge
#     openssl:           1.0.2p-h1de35cc_0                    --> 1.0.2p-h470a237_1         conda-forge
#     r-assertthat:      0.2.0-r343h889e2dd_0                 --> 0.2.0-r351h6115d3f_1      conda-forge
#     r-backports:       1.1.2-r343h7f474d2_0                 --> 1.1.2-r351hc070d10_1      conda-forge
#     r-base:            3.4.3-h9b62496_0                     --> 3.5.1-h4fe35fd_1          conda-forge
#     r-bh:              1.65.0_1-r343h889e2dd_0              --> 1.66.0_1-r351_1           conda-forge
#     r-bindr:           0.1-r343h889e2dd_0                   --> 0.1.1-r351h6115d3f_1      conda-forge
#     r-bindrcpp:        0.2-r343he124285_0                   --> 0.2.2-r351h9d2a408_1      conda-forge
#     r-bit:             1.1_12-r343h7f474d2_0                --> 1.1_12-r351h470a237_2     conda-forge
#     r-bit64:           0.9_7-r343h7f474d2_0                 --> 0.9_7-r351hc070d10_0      conda-forge
#     r-blob:            1.1.0-r343h889e2dd_0                 --> 1.1.1-r351_1              conda-forge
#     r-boot:            1.3_20-r343h889e2dd_0                --> 1.3_20-r351_0             conda-forge
#     r-broom:           0.4.3-r343h889e2dd_0                 --> 0.5.0-r351h6115d3f_2      conda-forge
#     r-callr:           1.0.0-r343h889e2dd_0                 --> 3.0.0-r351h6115d3f_0      conda-forge
#     r-caret:           6.0_78-r343h7f474d2_0                --> 6.0_80-r351hc070d10_1     conda-forge
#     r-catools:         1.17.1-r343he124285_4                --> 1.17.1.1-r351h9d2a408_2   conda-forge
#     r-cellranger:      1.1.0-r343h889e2dd_0                 --> 1.1.0-r351h6115d3f_1      conda-forge
#     r-cli:             1.0.0-r343h889e2dd_0                 --> 1.0.0-r351h6115d3f_1      conda-forge
#     r-clipr:           0.4.0-r343h889e2dd_0                 --> 0.4.1-r351h6115d3f_1      conda-forge
#     r-cluster:         2.0.6-r343h883f7c5_0                 --> 2.0.7_1-r351h364d78e_0    conda-forge
#     r-codetools:       0.2_15-r343h889e2dd_0                --> 0.2_15-r351h6115d3f_1     conda-forge
#     r-colorspace:      1.3_2-r343h7f474d2_0                 --> 1.3_2-r351hc070d10_2      conda-forge
#     r-config:          0.2-r343h889e2dd_0                   --> 0.3-r351h6115d3f_1        conda-forge
#     r-crayon:          1.3.4-r343h889e2dd_0                 --> 1.3.4-r351h6115d3f_1      conda-forge
#     r-curl:            3.1-r343h7f474d2_0                   --> 3.2-r351hc070d10_2        conda-forge
#     r-cvst:            0.2_1-r343h889e2dd_0                 --> 0.2_2-r351h6115d3f_0      conda-forge
#     r-data.table:      1.10.4_3-r343h7f474d2_0              --> 1.11.4-r351hc070d10_2     conda-forge
#     r-dbi:             0.7-r343h889e2dd_0                   --> 1.0.0-r351h6115d3f_1      conda-forge
#     r-dbplyr:          1.1.0-r343h889e2dd_0                 --> 1.2.2-r351h6115d3f_1      conda-forge
#     r-ddalpha:         1.3.1-r343h9f775be_0                 --> 1.3.4-r351he0ffe0d_1      conda-forge
#     r-deoptimr:        1.0_8-r343h889e2dd_0                 --> 1.0_8-r351h6115d3f_1      conda-forge
#     r-dichromat:       2.0_0-r343h889e2dd_4                 --> 2.0_0-r351hf348343_4
#     r-digest:          0.6.13-r343h7f474d2_0                --> 0.6.18-r351hc070d10_0     conda-forge
#     r-dimred:          0.1.0-r343h889e2dd_0                 --> 0.1.0-r351h6115d3f_2      conda-forge
#     r-dplyr:           0.7.4-r343he124285_0                 --> 0.7.6-r351h9d2a408_1      conda-forge
#     r-drr:             0.0.2-r343h889e2dd_0                 --> 0.0.3-r351h6115d3f_1      conda-forge
#     r-essentials:      3.4.3-r343_0                         --> 3.5.1-r351_0
#     r-evaluate:        0.10.1-r343h889e2dd_0                --> 0.11-r351h6115d3f_0       conda-forge
#     r-forcats:         0.2.0-r343h889e2dd_0                 --> 0.3.0-r351h6115d3f_1      conda-forge
#     r-foreach:         1.4.4-r343h889e2dd_0                 --> 1.4.4-r351h6115d3f_1      conda-forge
#     r-foreign:         0.8_69-r343h7f474d2_0                --> 0.8_71-r351hc070d10_2     conda-forge
#     r-formatr:         1.5-r343h889e2dd_0                   --> 1.5-r351h6115d3f_1        conda-forge
#     r-ggplot2:         2.2.1-r343h889e2dd_0                 --> 3.0.0-r351h6115d3f_1      conda-forge
#     r-glmnet:          2.0_13-r343h883f7c5_0                --> 2.0_16-r351h0b560c1_0
#     r-glue:            1.2.0-r343h7f474d2_0                 --> 1.3.0-r351h470a237_2      conda-forge
#     r-gower:           0.1.2-r343h7f474d2_0                 --> 0.1.2-r351hc070d10_2      conda-forge
#     r-gtable:          0.2.0-r343h889e2dd_0                 --> 0.2.0-r351h6115d3f_1      conda-forge
#     r-haven:           1.1.0-r343he124285_0                 --> 1.1.2-r351h9d2a408_2      conda-forge
#     r-hexbin:          1.27.1-r343h883f7c5_4                --> 1.27.2-r351h364d78e_2     conda-forge
#     r-highr:           0.6-r343h889e2dd_0                   --> 0.7-r351h6115d3f_1        conda-forge
#     r-hms:             0.4.0-r343h889e2dd_0                 --> 0.4.2-r351h6115d3f_0      conda-forge
#     r-htmltools:       0.3.6-r343he124285_0                 --> 0.3.6-r351hfc679d8_2      conda-forge
#     r-htmlwidgets:     0.9-r343h889e2dd_0                   --> 1.2-r351h6115d3f_0        conda-forge
#     r-httpuv:          1.3.5-r343he124285_0                 --> 1.4.5-r351hfc679d8_1      conda-forge
#     r-httr:            1.3.1-r343h889e2dd_0                 --> 1.3.1-r351h6115d3f_1      conda-forge
#     r-ipred:           0.9_6-r343h7f474d2_0                 --> 0.9_7-r351hc070d10_1      conda-forge
#     r-irdisplay:       0.4.4-r343h889e2dd_0                 --> 0.5.0-r351hf348343_0
#     r-irkernel:        0.8.11-r343_0                        --> 0.8.12-r351_0
#     r-iterators:       1.0.9-r343h889e2dd_0                 --> 1.0.10-r351h6115d3f_1     conda-forge
#     r-jsonlite:        1.5-r343h7f474d2_0                   --> 1.5-r351hc070d10_2        conda-forge
#     r-kernlab:         0.9_25-r343h9f775be_0                --> 0.9_27-r351h9d2a408_0     conda-forge
#     r-knitr:           1.18-r343h889e2dd_0                  --> 1.20-r351h6115d3f_1       conda-forge
#     r-lattice:         0.20_35-r343h7f474d2_0               --> 0.20_35-r351hc070d10_0    conda-forge
#     r-lava:            1.5.1-r343h889e2dd_0                 --> 1.6.3-r351h6115d3f_1      conda-forge
#     r-lazyeval:        0.2.1-r343h7f474d2_0                 --> 0.2.1-r351hc070d10_2      conda-forge
#     r-lubridate:       1.7.1-r343he124285_0                 --> 1.7.4-r351h9d2a408_1      conda-forge
#     r-maps:            3.2.0-r343h7f474d2_0                 --> 3.3.0-r351hc070d10_2      conda-forge
#     r-markdown:        0.8-r343h7f474d2_0                   --> 0.8-r351hc070d10_3        conda-forge
#     r-mass:            7.3_48-r343h7f474d2_0                --> 7.3_50-r351hc070d10_2     conda-forge
#     r-matrix:          1.2_12-r343h7f474d2_0                --> 1.2_14-r351hc070d10_2     conda-forge
#     r-mgcv:            1.8_22-r343h7f474d2_0                --> 1.8_24-r351hc070d10_2     conda-forge
#     r-mime:            0.5-r343h7f474d2_0                   --> 0.5-r351hc070d10_2        conda-forge
#     r-miniui:          0.1.1-r343h889e2dd_0                 --> 0.1.1.1-r351h6115d3f_0    conda-forge
#     r-mnormt:          1.5_5-r343h883f7c5_0                 --> 1.5_5-r351h364d78e_1      conda-forge
#     r-modelmetrics:    1.1.0-r343he124285_0                 --> 1.1.0-r351h9d2a408_2      conda-forge
#     r-modelr:          0.1.1-r343h889e2dd_0                 --> 0.1.2-r351h6115d3f_1      conda-forge
#     r-mongolite:       1.4-r343h7f474d2_0                   --> 1.6-r351h6402f54_0
#     r-munsell:         0.4.3-r343h889e2dd_0                 --> 0.5.0-r351h6115d3f_1      conda-forge
#     r-nlme:            3.1_131-r343h883f7c5_0               --> 3.1_137-r351h364d78e_0    conda-forge
#     r-nnet:            7.3_12-r343h7f474d2_0                --> 7.3_12-r351hc070d10_2     conda-forge
#     r-numderiv:        2016.8_1-r343h889e2dd_0              --> 2016.8_1-r351h6115d3f_1   conda-forge
#     r-odbc:            1.1.2-r343h0a44026_0                 --> 1.1.5-r351h0a44026_0
#     r-openssl:         0.9.9-r343h7f474d2_0                 --> 1.0.2-r351h9f97512_0      conda-forge
#     r-packrat:         0.4.8_1-r343h889e2dd_0               --> 0.4.9_3-r351h6115d3f_1    conda-forge
#     r-pbdzmq:          0.3_0-r343h0a44026_1                 --> 0.3_3-r351h32998d9_0
#     r-pillar:          1.0.1-r343h889e2dd_0                 --> 1.3.0-r351h6115d3f_0      conda-forge
#     r-pkgconfig:       2.0.1-r343h889e2dd_0                 --> 2.0.2-r351h6115d3f_1      conda-forge
#     r-pki:             0.1_5.1-r343h7f474d2_0               --> 0.1_5.1-r351hc070d10_0    conda-forge
#     r-plogr:           0.1_1-r343h889e2dd_0                 --> 0.2.0-r351h6115d3f_1      conda-forge
#     r-plyr:            1.8.4-r343he124285_0                 --> 1.8.4-r351h9d2a408_2      conda-forge
#     r-prodlim:         1.6.1-r343he124285_0                 --> 2018.04.18-r351h9d2a408_2 conda-forge
#     r-profvis:         0.3.4-r343h7f474d2_0                 --> 0.3.5-r351h6402f54_0
#     r-psych:           1.7.8-r343h889e2dd_0                 --> 1.8.4-r351h6115d3f_1      conda-forge
#     r-purrr:           0.2.4-r343h7f474d2_0                 --> 0.2.5-r351hc070d10_1      conda-forge
#     r-quantmod:        0.4_12-r343h889e2dd_0                --> 0.4_13-r351hf348343_0
#     r-r6:              2.2.2-r343h889e2dd_0                 --> 2.2.2-r351h6115d3f_1      conda-forge
#     r-randomforest:    4.6_12-r343h883f7c5_4                --> 4.6_14-r351h364d78e_0     conda-forge
#     r-rappdirs:        0.3.1-r343h7f474d2_0                 --> 0.3.1-r351hc070d10_2      conda-forge
#     r-rbokeh:          0.6.3-r343_0                         --> 0.6.3-r351_0
#     r-rcolorbrewer:    1.1_2-r343h889e2dd_0                 --> 1.1_2-r351h6115d3f_1      conda-forge
#     r-rcpp:            0.12.14-r343he124285_0               --> 0.12.17-r351h9d2a408_2    conda-forge
#     r-rcpproll:        0.2.2-r343he124285_0                 --> 0.3.0-r351h9d2a408_0      conda-forge
#     r-rcurl:           1.95_4.9-r343h7f474d2_0              --> 1.95_4.11-r351h86b9717_2  conda-forge
#     r-readr:           1.1.1-r343he124285_0                 --> 1.1.1-r351h9d2a408_2      conda-forge
#     r-readxl:          1.0.0-r343he124285_0                 --> 1.1.0-r351h9d2a408_2      conda-forge
#     r-recipes:         0.1.1-r343h889e2dd_0                 --> 0.1.3-r351h6115d3f_1      conda-forge
#     r-recommended:     3.4.3-r343_0                         --> 3.5.1-r351_1              conda-forge
#     r-rematch:         1.0.1-r343h889e2dd_0                 --> 1.0.1-r351h6115d3f_1      conda-forge
#     r-repr:            0.12.0-r343h889e2dd_0                --> 0.15.0-r351hf348343_0
#     r-reprex:          0.1.1-r343h889e2dd_0                 --> 0.2.0-r351h6115d3f_1      conda-forge
#     r-reshape2:        1.4.3-r343he124285_0                 --> 1.4.3-r351h9d2a408_2      conda-forge
#     r-rjava:           0.9_9-r343h7f474d2_0                 --> 0.9_10-r351h6402f54_0
#     r-rjdbc:           0.2_5-r343h889e2dd_0                 --> 0.2_7.1-r351hf348343_0
#     r-rlang:           0.1.6-r343h7f474d2_0                 --> 0.2.2-r351h470a237_0      conda-forge
#     r-rmarkdown:       1.8-r343h889e2dd_0                   --> 1.10-r351h6115d3f_1       conda-forge
#     r-robustbase:      0.92_8-r343h883f7c5_0                --> 0.93_2-r351h364d78e_0     conda-forge
#     r-rpart:           4.1_11-r343h7f474d2_0                --> 4.1_13-r351hc070d10_2     conda-forge
#     r-rprojroot:       1.3_1-r343h889e2dd_0                 --> 1.3_2-r351h6115d3f_1      conda-forge
#     r-rsconnect:       0.8.5-r343h889e2dd_0                 --> 0.8.8-r351h6115d3f_0      conda-forge
#     r-rstudioapi:      0.7-r343h889e2dd_0                   --> 0.7-r351h6115d3f_1        conda-forge
#     r-rvest:           0.3.2-r343h889e2dd_0                 --> 0.3.2-r351h6115d3f_1      conda-forge
#     r-scales:          0.5.0-r343he124285_0                 --> 1.0.0-r351h9d2a408_1      conda-forge
#     r-selectr:         0.3_1-r343h889e2dd_0                 --> 0.4_1-r351h6115d3f_0      conda-forge
#     r-sfsmisc:         1.1_1-r343h889e2dd_0                 --> 1.1_2-r351h6115d3f_0      conda-forge
#     r-shiny:           1.0.5-r343h889e2dd_0                 --> 1.1.0-r351_0              conda-forge
#     r-sourcetools:     0.1.6-r343he124285_0                 --> 0.1.7-r351hfc679d8_0      conda-forge
#     r-sparklyr:        0.8.2-r343ha5884a4_0                 --> 0.8.4-r351h6115d3f_1      conda-forge
#     r-stringi:         1.1.6-r343he124285_0                 --> 1.2.4-r351h9d2a408_1      conda-forge
#     r-stringr:         1.2.0-r343h889e2dd_0                 --> 1.3.1-r351h6115d3f_1      conda-forge
#     r-survival:        2.41_3-r343h7f474d2_0                --> 2.42_6-r351hc070d10_1     conda-forge
#     r-tibble:          1.4.1-r343h7f474d2_0                 --> 1.4.2-r351hc070d10_2      conda-forge
#     r-tidyr:           0.7.2-r343he124285_0                 --> 0.8.1-r351h9d2a408_2      conda-forge
#     r-tidyselect:      0.2.3-r343he124285_0                 --> 0.2.4-r351h9d2a408_2      conda-forge
#     r-tidyverse:       1.2.1-r343h889e2dd_0                 --> 1.2.1-r351h6115d3f_1      conda-forge
#     r-timedate:        3042.101-r343h889e2dd_0              --> 3043.102-r351h6115d3f_0   conda-forge
#     r-ttr:             0.23_2-r343h883f7c5_0                --> 0.23_3-r351h0b560c1_0
#     r-utf8:            1.1.2-r343h7f474d2_0                 --> 1.1.4-r351hc070d10_0      conda-forge
#     r-viridislite:     0.2.0-r343h889e2dd_0                 --> 0.3.0-r351h6115d3f_1      conda-forge
#     r-withr:           2.1.1-r343h889e2dd_0                 --> 2.1.2-r351h6115d3f_0      conda-forge
#     r-xml2:            1.1.1-r343he124285_0                 --> 1.2.0-r351h9d2a408_2      conda-forge
#     r-xtable:          1.8_2-r343h889e2dd_0                 --> 1.8_3-r351_0              conda-forge
#     r-xts:             0.10_1-r343h883f7c5_0                --> 0.11_1-r351hc070d10_0     conda-forge
#     r-yaml:            2.1.16-r343h7f474d2_0                --> 2.2.0-r351hc070d10_1      conda-forge
#     r-zoo:             1.8_0-r343h7f474d2_0                 --> 1.8_3-r351hc070d10_0      conda-forge
#     tk:                8.6.7-h35a86e2_3                     --> 8.6.8-ha92aebf_0          conda-forge
#     unixodbc:          2.3.6-h3efe00b_0                     --> 2.3.7-h09ba92c_0          conda-forge
#
# The following packages will be DOWNGRADED:
#
#     gsl:               2.4-h1de35cc_4                       --> 2.2.1-h002c638_3
#     pango:             1.41.0-h3bae10e_0                    --> 1.40.14-0                 conda-forge
#     r-base64enc:       0.1_3-r343h7f474d2_4                 --> 0.1_3-r351hc070d10_2      conda-forge
#     r-bitops:          1.0_6-r343h7f474d2_4                 --> 1.0_6-r351hc070d10_2      conda-forge
#     r-class:           7.3_14-r343h7f474d2_4                --> 7.3_14-r351hc070d10_2     conda-forge
#     r-kernsmooth:      2.23_15-r343h883f7c5_4               --> 2.23_15-r351h364d78e_2    conda-forge
#     r-labeling:        0.3-r343h889e2dd_4                   --> 0.3-r351h6115d3f_1        conda-forge
#     r-magrittr:        1.5-r343h889e2dd_4                   --> 1.5-r351h6115d3f_1        conda-forge
#     r-rjsonio:         1.3_0-r343he124285_4                 --> 1.3_0-r351h9d2a408_2      conda-forge
#     r-spatial:         7.3_11-r343h7f474d2_4                --> 7.3_11-r351hc070d10_2     conda-forge
#     r-uuid:            0.1_2-r343h7f474d2_4                 --> 0.1_2-r351hc070d10_1      conda-forge
#     r-whisker:         0.3_2-r343h889e2dd_4                 --> 0.3_2-r351h6115d3f_1      conda-forge
#
#
# Downloading and Extracting Packages
# r-plyr-1.8.4         | 836 KB    | ##################################### | 100%
# freetype-2.8.1       | 830 KB    | ##################################### | 100%
# pango-1.40.14        | 520 KB    | ##################################### | 100%
# r-cvst-0.2_2         | 100 KB    | ##################################### | 100%
# r-munsell-0.5.0      | 243 KB    | ##################################### | 100%
# r-repr-0.15.0        | 105 KB    | ##################################### | 100%
# r-dimred-0.1.0       | 620 KB    | ##################################### | 100%
# xorg-libxrender-0.9. | 24 KB     | ##################################### | 100%
# r-modelr-0.1.2       | 211 KB    | ##################################### | 100%
# xorg-libx11-1.6.6    | 841 KB    | ##################################### | 100%
# r-rcurl-1.95_4.11    | 861 KB    | ##################################### | 100%
# r-tibble-1.4.2       | 227 KB    | ##################################### | 100%
# r-caret-6.0_80       | 5.9 MB    | ##################################### | 100%
# r-quantmod-0.4_13    | 952 KB    | ##################################### | 100%
# r-rpart-4.1_13       | 912 KB    | ##################################### | 100%
# r-lazyeval-0.2.1     | 158 KB    | ##################################### | 100%
# r-xtable-1.8_3       | 738 KB    | ##################################### | 100%
# r-rjava-0.9_10       | 672 KB    | ##################################### | 100%
# jpeg-9c              | 245 KB    | ##################################### | 100%
# r-yaml-2.2.0         | 111 KB    | ##################################### | 100%
# r-digest-0.6.18      | 154 KB    | ##################################### | 100%
# r-data.table-1.11.4  | 1.4 MB    | ##################################### | 100%
# r-recommended-3.5.1  | 3 KB      | ##################################### | 100%
# r-sourcetools-0.1.7  | 57 KB     | ##################################### | 100%
# r-recipes-0.1.3      | 1.2 MB    | ##################################### | 100%
# r-irkernel-0.8.12    | 199 KB    | ##################################### | 100%
# r-irdisplay-0.5.0    | 34 KB     | ##################################### | 100%
# r-rlang-0.2.2        | 785 KB    | ##################################### | 100%
# r-base-3.5.1         | 22.8 MB   | ##################################### | 100%
# r-rappdirs-0.3.1     | 96 KB     | ##################################### | 100%
# r-utf8-1.1.4         | 157 KB    | ##################################### | 100%
# r-rvest-0.3.2        | 888 KB    | ##################################### | 100%
# r-sparklyr-0.8.4     | 2.7 MB    | ##################################### | 100%
# r-lubridate-1.7.4    | 1.1 MB    | ##################################### | 100%
# r-backports-1.1.2    | 52 KB     | ##################################### | 100%
# r-zoo-1.8_3          | 1.1 MB    | ##################################### | 100%
# r-xfun-0.3           | 151 KB    | ##################################### | 100%
# r-rematch-1.0.1      | 17 KB     | ##################################### | 100%
# r-tinytex-0.8        | 90 KB     | ##################################### | 100%
# r-drr-0.0.3          | 172 KB    | ##################################### | 100%
# r-ps-1.1.0           | 188 KB    | ##################################### | 100%
# r-fansi-0.3.0        | 165 KB    | ##################################### | 100%
# r-pkgconfig-2.0.2    | 23 KB     | ##################################### | 100%
# r-randomforest-4.6_1 | 227 KB    | ##################################### | 100%
# r-knitr-1.20         | 1.0 MB    | ##################################### | 100%
# xorg-xextproto-7.3.0 | 27 KB     | ##################################### | 100%
# r-kernlab-0.9_27     | 2.1 MB    | ##################################### | 100%
# r-callr-3.0.0        | 189 KB    | ##################################### | 100%
# r-ipred-0.9_7        | 395 KB    | ##################################### | 100%
# r-mgcv-1.8_24        | 2.4 MB    | ##################################### | 100%
# geopy-1.17.0         | 49 KB     | ##################################### | 100%
# r-uuid-0.1_2         | 20 KB     | ##################################### | 100%
# r-highr-0.7          | 46 KB     | ##################################### | 100%
# r-robustbase-0.93_2  | 3.0 MB    | ##################################### | 100%
# r-rcpproll-0.3.0     | 130 KB    | ##################################### | 100%
# r-iterators-1.0.10   | 333 KB    | ##################################### | 100%
# pthread-stubs-0.4    | 5 KB      | ##################################### | 100%
# prometheus_client-0. | 32 KB     | ##################################### | 100%
# r-glue-1.3.0         | 93 KB     | ##################################### | 100%
# gsl-2.2.1            | 2.7 MB    | ##################################### | 100%
# geographiclib-1.49   | 32 KB     | ##################################### | 100%
# conda-4.5.11         | 651 KB    | ##################################### | 100%
# r-readxl-1.1.0       | 873 KB    | ##################################### | 100%
# r-tidyr-0.8.1        | 443 KB    | ##################################### | 100%
# xorg-libsm-1.2.3     | 24 KB     | ##################################### | 100%
# r-promises-1.0.1     | 181 KB    | ##################################### | 100%
# libedit-3.1.20170329 | 155 KB    | ##################################### | 100%
# ncurses-6.1          | 1.2 MB    | ##################################### | 100%
# r-base64enc-0.1_3    | 42 KB     | ##################################### | 100%
# r-xml2-1.2.0         | 367 KB    | ##################################### | 100%
# r-formatr-1.5        | 157 KB    | ##################################### | 100%
# xorg-renderproto-0.1 | 8 KB      | ##################################### | 100%
# r-bitops-1.0_6       | 37 KB     | ##################################### | 100%
# r-class-7.3_14       | 102 KB    | ##################################### | 100%
# r-lattice-0.20_35    | 1.1 MB    | ##################################### | 100%
# r-maps-3.3.0         | 3.4 MB    | ##################################### | 100%
# r-broom-0.5.0        | 1.9 MB    | ##################################### | 100%
# r-pillar-1.3.0       | 168 KB    | ##################################### | 100%
# r-psych-1.8.4        | 5.5 MB    | ##################################### | 100%
# r-survival-2.42_6    | 4.3 MB    | ##################################### | 100%
# r-foreign-0.8_71     | 273 KB    | ##################################### | 100%
# r-kernsmooth-2.23_15 | 94 KB     | ##################################### | 100%
# r-spatial-7.3_11     | 147 KB    | ##################################### | 100%
# r-bindr-0.1.1        | 20 KB     | ##################################### | 100%
# r-sfsmisc-1.1_2      | 617 KB    | ##################################### | 100%
# r-catools-1.17.1.1   | 217 KB    | ##################################### | 100%
# r-dbi-1.0.0          | 880 KB    | ##################################### | 100%
# r-hms-0.4.2          | 71 KB     | ##################################### | 100%
# r-labeling-0.3       | 64 KB     | ##################################### | 100%
# r-markdown-0.8       | 133 KB    | ##################################### | 100%
# krb5-1.14.6          | 1.2 MB    | ##################################### | 100%
# r-magic-1.5_8        | 587 KB    | ##################################### | 100%
# r-rjdbc-0.2_7.1      | 101 KB    | ##################################### | 100%
# r-ddalpha-1.3.4      | 1.2 MB    | ##################################### | 100%
# r-tidyverse-1.2.1    | 97 KB     | ##################################### | 100%
# r-rprojroot-1.3_2    | 92 KB     | ##################################### | 100%
# r-geometry-0.3_6     | 409 KB    | ##################################### | 100%
# r-timedate-3043.102  | 1.5 MB    | ##################################### | 100%
# r-glmnet-2.0_16      | 1.4 MB    | ##################################### | 100%
# r-whisker-0.3_2      | 77 KB     | ##################################### | 100%
# r-jsonlite-1.5       | 1.1 MB    | ##################################### | 100%
# r-forcats-0.3.0      | 222 KB    | ##################################### | 100%
# r-scales-1.0.0       | 571 KB    | ##################################### | 100%
# r-httpuv-1.4.5       | 491 KB    | ##################################### | 100%
# r-boot-1.3_20        | 624 KB    | ##################################### | 100%
# r-profvis-0.3.5      | 164 KB    | ##################################### | 100%
# r-bit64-0.9_7        | 453 KB    | ##################################### | 100%
# r-modelmetrics-1.1.0 | 127 KB    | ##################################### | 100%
# r-odbc-1.1.5         | 431 KB    | ##################################### | 100%
# r-numderiv-2016.8_1  | 123 KB    | ##################################### | 100%
# r-ttr-0.23_3         | 505 KB    | ##################################### | 100%
# r-miniui-0.1.1.1     | 50 KB     | ##################################### | 100%
# r-blob-1.1.1         | 27 KB     | ##################################### | 100%
# xorg-libxext-1.3.3   | 42 KB     | ##################################### | 100%
# r-reshape2-1.4.3     | 139 KB    | ##################################### | 100%
# r-colorspace-1.3_2   | 507 KB    | ##################################### | 100%
# r-evaluate-0.11      | 75 KB     | ##################################### | 100%
# xorg-kbproto-1.0.7   | 26 KB     | ##################################### | 100%
# libxcb-1.13          | 344 KB    | ##################################### | 100%
# r-bindrcpp-0.2.2     | 106 KB    | ##################################### | 100%
# r-config-0.3         | 38 KB     | ##################################### | 100%
# r-rbokeh-0.6.3       | 4.1 MB    | ##################################### | 100%
# r-pbdzmq-0.3_3       | 387 KB    | ##################################### | 100%
# r-essentials-3.5.1   | 5 KB      | ##################################### | 100%
# r-mongolite-1.6      | 331 KB    | ##################################### | 100%
# r-prettyunits-1.0.2  | 34 KB     | ##################################### | 100%
# r-pls-2.7_0          | 1.2 MB    | ##################################### | 100%
# r-deoptimr-1.0_8     | 55 KB     | ##################################### | 100%
# r-viridislite-0.3.0  | 63 KB     | ##################################### | 100%
# notebook-5.7.0       | 7.3 MB    | ##################################### | 100%
# r-httr-1.3.1         | 439 KB    | ##################################### | 100%
# r-haven-1.1.2        | 354 KB    | ##################################### | 100%
# r-later-0.7.3        | 117 KB    | ##################################### | 100%
# r-pki-0.1_5.1        | 104 KB    | ##################################### | 100%
# r-selectr-0.4_1      | 368 KB    | ##################################### | 100%
# r-prodlim-2018.04.18 | 407 KB    | ##################################### | 100%
# r-packrat-0.4.9_3    | 460 KB    | ##################################### | 100%
# r-nlme-3.1_137       | 2.2 MB    | ##################################### | 100%
# r-bh-1.66.0_1        | 10.0 MB   | ##################################### | 100%
# r-mass-7.3_50        | 1.1 MB    | ##################################### | 100%
# ca-certificates-2018 | 136 KB    | ##################################### | 100%
# r-assertthat-0.2.0   | 68 KB     | ##################################### | 100%
# r-openssl-1.0.2      | 1.1 MB    | ##################################### | 100%
# r-tidyselect-0.2.4   | 152 KB    | ##################################### | 100%
# r-rjsonio-1.3_0      | 1020 KB   | ##################################### | 100%
# xorg-libice-1.0.9    | 57 KB     | ##################################### | 100%
# r-squarem-2017.10_1  | 300 KB    | ##################################### | 100%
# r-rmarkdown-1.10     | 2.4 MB    | ##################################### | 100%
# r-gtable-0.2.0       | 95 KB     | ##################################### | 100%
# _r-mutex-1.0.0       | 2 KB      | ##################################### | 100%
# r-cellranger-1.1.0   | 105 KB    | ##################################### | 100%
# r-magrittr-1.5       | 164 KB    | ##################################### | 100%
# r-r6-2.2.2           | 275 KB    | ##################################### | 100%
# r-readr-1.1.1        | 700 KB    | ##################################### | 100%
# r-plogr-0.2.0        | 18 KB     | ##################################### | 100%
# r-purrr-0.2.5        | 282 KB    | ##################################### | 100%
# r-rcolorbrewer-1.1_2 | 58 KB     | ##################################### | 100%
# r-shiny-1.1.0        | 3.2 MB    | ##################################### | 100%
# r-curl-3.2           | 406 KB    | ##################################### | 100%
# openssl-1.0.2p       | 2.9 MB    | ##################################### | 100%
# r-rsconnect-0.8.8    | 504 KB    | ##################################### | 100%
# xorg-libxdmcp-1.1.2  | 15 KB     | ##################################### | 100%
# r-hexbin-1.27.2      | 865 KB    | ##################################### | 100%
# r-dplyr-0.7.6        | 1.8 MB    | ##################################### | 100%
# r-mnormt-1.5_5       | 91 KB     | ##################################### | 100%
# unixodbc-2.3.7       | 271 KB    | ##################################### | 100%
# r-htmltools-0.3.6    | 192 KB    | ##################################### | 100%
# r-htmlwidgets-1.2    | 691 KB    | ##################################### | 100%
# r-bit-1.1_12         | 224 KB    | ##################################### | 100%
# r-reprex-0.2.0       | 397 KB    | ##################################### | 100%
# r-gower-0.1.2        | 48 KB     | ##################################### | 100%
# r-processx-3.2.0     | 167 KB    | ##################################### | 100%
# r-mime-0.5           | 48 KB     | ##################################### | 100%
# r-dichromat-2.0_0    | 151 KB    | ##################################### | 100%
# r-nnet-7.3_12        | 126 KB    | ##################################### | 100%
# r-ggplot2-3.0.0      | 3.5 MB    | ##################################### | 100%
# r-foreach-1.4.4      | 403 KB    | ##################################### | 100%
# r-abind-1.4_5        | 66 KB     | ##################################### | 100%
# xorg-libxau-1.0.8    | 11 KB     | ##################################### | 100%
# xorg-xproto-7.0.31   | 72 KB     | ##################################### | 100%
# r-rstudioapi-0.7     | 134 KB    | ##################################### | 100%
# r-clipr-0.4.1        | 50 KB     | ##################################### | 100%
# r-matrix-1.2_14      | 3.6 MB    | ##################################### | 100%
# r-rcpp-0.12.17       | 3.5 MB    | ##################################### | 100%
# r-lava-1.6.3         | 2.2 MB    | ##################################### | 100%
# r-stringr-1.3.1      | 186 KB    | ##################################### | 100%
# r-stringi-1.2.4      | 11.7 MB   | ##################################### | 100%
# r-codetools-0.2_15   | 91 KB     | ##################################### | 100%
# r-withr-2.1.2        | 172 KB    | ##################################### | 100%
# tk-8.6.8             | 3.0 MB    | ##################################### | 100%
# r-dbplyr-1.2.2       | 534 KB    | ##################################### | 100%
# certifi-2018.8.24    | 139 KB    | ##################################### | 100%
# r-cli-1.0.0          | 323 KB    | ##################################### | 100%
# r-cluster-2.0.7_1    | 537 KB    | ##################################### | 100%
# r-xts-0.11_1         | 904 KB    | ##################################### | 100%
# r-crayon-1.3.4       | 745 KB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Solving environment: done
#
# # All requested packages already installed.
#
# Libraries imported.

# %%
import folium

# %%
address = 'Toronto'

geolocator = Nominatim()
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Toronto are {}, {}.'.format(latitude, longitude))
# Out:
# /anaconda3/lib/python3.6/site-packages/geopy/geocoders/osm.py:143: UserWarning: Using Nominatim with the default "geopy/1.17.0" `user_agent` is strongly discouraged, as it violates Nominatim's ToS https://operations.osmfoundation.org/policies/nominatim/ and may possibly cause 403 and 429 HTTP errors. Please specify a custom `user_agent` with `Nominatim(user_agent="my-application")` or by overriding the default `user_agent`: `geopy.geocoders.options.default_user_agent = "my-application"`. In geopy 2.0 this will become an exception.
#   UserWarning
# The geograpical coordinate of Toronto are 43.653963, -79.387207.

# %%
Toronto = geo_toronto[geo_toronto['Borough'].str.contains("Toronto", case=False)].reset_index(drop=True)


print(Toronto.shape)
Toronto.head()
# Out:
# (38, 5)
#   Postalcode          Borough                   Neighbourhood   Latitude  \
# 0        M4E     East Toronto                     The Beaches  43.676357
# 1        M4K     East Toronto    The Danforth West, Riverdale  43.679557
# 2        M4L     East Toronto  The Beaches West, India Bazaar  43.668999
# 3        M4M     East Toronto                 Studio District  43.659526
# 4        M4N  Central Toronto                   Lawrence Park  43.728020
#
#    Longitude
# 0 -79.293031
# 1 -79.352188
# 2 -79.315572
# 3 -79.340923
# 4 -79.388790

# %%
from geopy.geocoders import Nominatim 

location = Nominatim().geocode('Toronto, Canada')
# Out:
# /anaconda3/lib/python3.6/site-packages/geopy/geocoders/osm.py:143: UserWarning: Using Nominatim with the default "geopy/1.17.0" `user_agent` is strongly discouraged, as it violates Nominatim's ToS https://operations.osmfoundation.org/policies/nominatim/ and may possibly cause 403 and 429 HTTP errors. Please specify a custom `user_agent` with `Nominatim(user_agent="my-application")` or by overriding the default `user_agent`: `geopy.geocoders.options.default_user_agent = "my-application"`. In geopy 2.0 this will become an exception.
#   UserWarning

# %%
import folium

map_toronto = folium.Map(location=[location.latitude, location.longitude], zoom_start=11)

# add markers to map
for lat, lng, neighborhood in zip(Toronto['Latitude'], Toronto['Longitude'], Toronto['Neighbourhood']):
    label = '{}'.format(neighborhood)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7).add_to(map_toronto) 
map_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
